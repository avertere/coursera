# %%
#To install ipython-sql simply run the following 
# command in a Jupyter Notebook:
# !pip install ipython-sql

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite://

# %% [markdown]
# # SQL for Data Science

# %% [markdown]
# ## Week 1
#
# ### Selecting and Retrieving Data with SQL
#
# **What is SQL?**
#
# Structured Query Language (SQL) - computer language for relational database management and data manipulation
#
# Often used to query, insert, update and modify data.Used to communicate with database.
#
# SQL is a non-procedural language:
# - Cannot wrute complete applications
# - Simple, but powerful
#
# How is SQL used? SQL is all about data.
# - Read/retrieve data
# - Write data: add data to a table
# - Update data: insert new data
#
# Relational Database Management Systems?
# - Microsoft SQL Server
# - MySQL
# - IBM DB@ Oracle
# - Apache Open Office Base
# - Sybase ASE
# - SQLite (What we're gong to use in this class - agrees with the one I've installed in this jupyter-notebook)
# - PostgreSQL
#
# Before dive on code itself, it is important to understant data base models. For this, it is important to
#
# **Data Models - Part 1: Thinkimg about Your Data**
#
# *Understand your data:*
# - Understand the business process or subject matter the data is modeled after
# - Know the business rules
# - Understand how your data is organized and structured in the table (modeled)
#
# *Why This is Worthwhile?* Get more accurate results, speed up your work and have less rework.
#
# When writting querys, it is important to understand what a database is.
#
# - *Database*: A container (usuallu a file or a set of files) to storage organized data; a set of related information. Within the database we have Tables.
# - *Tables*: A structured list of data or a specific type. In a row we'll have columns and rows.
# - *Column*: A single field in a table - all tables are made up of one or more columns
# - *Row*: A record in a table.
#
# **Data Models - Part 2: The Evolution of Data Models**
#
# Data modelling is what we use to organize information for multiple tables and how they relate to each other together. This helps tremendously in providing structure to the information in the system. Usually a data model represents a business process and it can also help you understand a business process.
#
# *Types of data models: there are a lot of them.*
# ![image.png](attachment:image.png)
#
# *Evolution of Data Models:*
#
# ![image-2.png](attachment:image-2.png)
#
# *We're going *
# *SQL in a Big Data World*
# *NoSQL - Not Only SQL*
# A mechanis for storage and retrieval of unstructured data modeled by means other than tabular relations in relational databases.
#
#
# **Data Models, Part 3: Relational vs. Transactional Models**
#
# - *Relational Model*: a database design that shows the relationships between the different tables and this is really used to optimize querying data, making it easy and intuitive to access the data.
# - *Transactional Model*: you can think of as a more operational database. If you are in healthcare, for example, you may have a transactional database that is used to store all the claims information and then this information may not be stored in a great way for querying and using it for analysis. In fact, you may need to take and extract that transactional information from the database and move it into a relational model.
#
# We're going to work more on relational model. The building blocks for this relational model are really three simple things
#
# 1. *Entity:* person, place thing or event - distinguishable, unique, and distinct
# 2. *Attribute:* A characteristic of an entity
# 3. *Relationship:* describe association among entities
#     - one-to-many: customer to invoices
#     - many-to-many: many student to many classes
#     - one-to-one: manger to store
#
# To exploit the relationships, we use *ER Diagrams*. It is composed of entity types and specifies relationships that can exist between instances of those entity types.
#
# ![image-3.png](attachment:image-3.png)
#
# This visual understand is helpful also for binf tables toghether. For bind, we use
#
# - *Primary Key:* a column(or set of columns) whose values uniquely idenify every row in a table
# - *Foreign Key:* one or more columns that can be used together to identify a single row in another table
#
# *ER  Diagram Notation*:
# - Chen Notation
# - Crow's Foot Notation
# - UML Class Diagram Notation
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
#
# **Retrieving Data with a SELECT Statement**
#
# *The SELECT statement*
#
# Need to specify two pieces of information to use a SELECT statement: what you want and where you want to select it from.
#
# ![image-8.png](attachment:image-8.png)
#
# `SELECT PROD_NAME
# FROM Products;`
#
# *Retrieving Multiple Columns*
# Add multiple column names, be sure to use comma.
#
# ![image-9.png](attachment:image-9.png)
#
# `SELECT prod_name
#        ,prod_id
#        ,prod_price
# FROM Products;`
#
# *Retrieving Multiple Columns Using a Wildcard*
# Request all columns by using the asterisk(*) wildcard character instead of column names
#
# ![image-10.png](attachment:image-10.png)
#
# `SELECT *
# FROM Products;`
#
# *Limit results*
#
# You might only want to see a sample of the data
#
# `SELECT columns you wish to see
# FROM specific table
# LIMIT number of records`
#
#
# *Limiting results using different Data Base Management syntaxes*
#
# ![image-11.png](attachment:image-11.png)
#
#
# **Creating Tables**
#
# ![image-12.png](attachment:image-12.png)
